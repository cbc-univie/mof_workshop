# %% [markdown]
# # Workshop: ML Potentials for Porous Materials MD
#
# ### Brief plan
#
# Set up a selected metal–organic framework (MOF) and a small adsorbate (CO2/H2O).
# - Run short NVT MD with a pretrained ML potential (MACE).
# - Visualize structures and trajectories.
# - Analyze adsorption via radial distribution functions (RDFs).

# %% [markdown]
# ### Simulations with ASE
#
# ASE (Atomic Simulation Environment) is a Python‑based toolkit for setting up, running, and analyzing atomistic simulations. You can run molecular dynamics (MD) with ASE’s built‑in MD engines, or connect to external codes via “calculators” (e.g., LAMMPS, MACE, VASP). In this role, ASE acts as an interface between your Python workflow and a variety of simulation backends.
#
# Therefore it is versatile as you have:
#
# - One consistent Atoms object, I/O, visualization
# - Swappable calculators (ML potentials, classical force fields, DFT)
#
# ASE overview: https://wiki.fysik.dtu.dk/ase/

# %% [markdown]
# ### Links to structures
#
#
# - CCDC (CIFs): https://www.ccdc.cam.ac.uk/structures/ (requires account to download structures)
# - CoRE MOF database: https://zenodo.org/records/14184621
# - Materials Project: https://materialsproject.org/ (requires account)
# - MOFdb: https://mof.tech.northwestern.edu/
#
# Tip: Prefer solvent/guest-free, charge-balanced CIFs; check for disorder/partial occupancies.
#
# Alternatively use the file provided: 02_uio-66.cif (recommended due to time constraints).

# %% [markdown]
# ### A first look
#
# We’ll start by loading the selected MOF and inspecting its cell, composition, and basic geometry.
# For quick inspections you can use:

# %%
from ase.io import read
from ase.visualize import view

# %% [markdown]
# ### Loading Coordinates
#
# We can load the coordinates into an ASE Atoms object. You can name the variable whatever you like; most examples use atoms.

# %%
atoms = read("02_uio-66.cif")

# %% [markdown]
# ### Visualizing structures and trajectories
#
# ASE includes an integrated viewer for quick visualization of structures and, later, trajectories; if you prefer external tools, you can also use VMD/Avogadro/Mercury/Ovito to view your coordinates.

# %%
view(atoms, viewer="x3d")
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 51.39439573724158">
#     <group/>
#   </viewpoint>
#   <transform translation="-7.28006416815 -6.304565965861845 -5.943857802369214">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 14.5601283363 0.0 0.0 21.841421739745307 12.60913193172369 0.0 7.281293403445308 12.60913193172369 0.0 0 0 0"/>
#             </lineset>
# ...

# %% [markdown]
# ### Basic structure info
#
# Let’s print the number of atoms, the unit cell (a, b, c, α, β, γ), and the cell volume.

# %%
print(len(atoms))
print(atoms.get_volume())
print(atoms.cell.cellpar())
# Out:
# 114
# 2182.472592468902
# [14.56012834 14.56047533 14.56002847 59.99553422 59.99732562 59.99520284]

# %% [markdown]
# ### Adding the adsorbate
#
# You can choose either CO2 or H2O.
# We need the following module for that:

# %%
from ase.build import molecule

# %%
co2 = molecule('CO2')
#h2o = molecule('H2O')

# %% [markdown]
# We place the molecule in the middle of the cell as the framework has no atoms there

# %%
com = atoms.get_cell().sum(axis=0) / 2
co2.translate(com )

# %% [markdown]
# Now we simply combine the two structures

# %%
system = atoms + co2
system.wrap()

# %% [markdown]
# Quick sanity check?
#
# We can verify the chemical formula or the length of the atoms object

# %%
print(atoms.get_chemical_formula())
print(system.get_chemical_formula())
# Out:
# C48H28O32Zr6
# C49H28O34Zr6

# %% [markdown]
# We see that we added one C and two O.

# %%
print(len(atoms))
print(len(system))
# Out:
# 114
# 117

# %% [markdown]
# We can see that we have three atoms more.
#
# We can also take a look at the system.

# %%
view(system, viewer="x3d")
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 51.39439573724158">
#     <group/>
#   </viewpoint>
#   <transform translation="-7.28006416815 -6.304565965861845 -5.943857802369214">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 14.5601283363 0.0 0.0 21.841421739745307 12.60913193172369 0.0 7.281293403445308 12.60913193172369 0.0 0 0 0"/>
#             </lineset>
# ...

# %% [markdown]
# ### Save the new combined structure
#
# Now that we evaluated the structure is correct we can save it to an input structure. ASE can write many coordinate formats such as cif/PDB or xyz.

# %%
from ase.io import write

# %%
write("03_structure.cif", system)

# %% [markdown]
# #### Congratulations, you created a starting structure for adsorption in MOFs!
